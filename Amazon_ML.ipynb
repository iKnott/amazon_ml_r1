# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
test_csv = pd.read_csv('Test.csv')
train_csv= pd.read_csv('Train.csv')
subm_csv = pd.read_csv('Submission.csv')

# %%
train_csv.head(3)
# Out:
#    EmpID  EmpName LanguageOfCommunication  Age  Gender  \
# 0  11041     John                 English   35    Male
# 1  15079  William                 English   26    Male
# 2  18638    James                 English   36  Female
#
#   JobProfileIDApplyingFor HighestDegree             DegreeBranch  \
# 0                 JR85289        B.Tech               Electrical
# 1                 JR87525        B.Tech  Artificial Intelligence
# 2                 JR87525           PhD         Computer Science
#
#   GraduatingInstitute  LatestDegreeCGPA  ...  CurrentCTC  ExpectedCTC  \
# 0              Tier 1                 7  ...          21           26
# 1              Tier 3                 7  ...          15           19
# 2              Tier 1                 6  ...          15           24
#
#    MartialStatus  EmpScore CurrentDesignation  CurrentCompanyType  \
# 0        Married         5                SSE          Enterprise
# ...

# %%
train_csv.isnull().sum()
# Out:
# EmpID                         0
# EmpName                       0
# LanguageOfCommunication       0
# Age                           0
# Gender                        0
# JobProfileIDApplyingFor       0
# HighestDegree                 0
# DegreeBranch                  0
# GraduatingInstitute           0
# LatestDegreeCGPA              0
# YearsOfExperince              0
# GraduationYear                0
# CurrentCTC                    0
# ExpectedCTC                   0
# MartialStatus                 0
# EmpScore                      0
# CurrentDesignation            0
# CurrentCompanyType            0
# DepartmentInCompany           0
# TotalLeavesTaken              0
# BiasInfluentialFactor      3336
# FitmentPercent                0
# dtype: int64

# %%
train_csv.BiasInfluentialFactor.value_counts()
# Out:
# DegreeBranch          2858
# Gender                2605
# YearsOfExperince      1561
# CurrentCompanyType    1174
# EmpScore               659
# HighestDegree          582
# Ethinicity             328
# MartialStatus          280
# LatestDegreeCGPA       262
# Name: BiasInfluentialFactor, dtype: int64

# %%
train_csv['BiasInfluentialFactor'] = train_csv['BiasInfluentialFactor'].fillna(0)

# %%
train_csv = train_csv.replace(to_replace =0,value = "Never")

# %%
train_csv.head(3)
# Out:
#    EmpID  EmpName LanguageOfCommunication  Age  Gender  \
# 0  11041     John                 English   35    Male
# 1  15079  William                 English   26    Male
# 2  18638    James                 English   36  Female
#
#   JobProfileIDApplyingFor HighestDegree             DegreeBranch  \
# 0                 JR85289        B.Tech               Electrical
# 1                 JR87525        B.Tech  Artificial Intelligence
# 2                 JR87525           PhD         Computer Science
#
#   GraduatingInstitute  LatestDegreeCGPA  ...  CurrentCTC  ExpectedCTC  \
# 0              Tier 1                 7  ...          21           26
# 1              Tier 3                 7  ...          15           19
# 2              Tier 1                 6  ...          15           24
#
#    MartialStatus  EmpScore CurrentDesignation  CurrentCompanyType  \
# 0        Married         5                SSE          Enterprise
# ...

# %%
list_of = train_csv['BiasInfluentialFactor'].value_counts()

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
train_new = train_csv

# %%
train_new['BiasInfluentialFactor'] = le.fit_transform(train_new.BiasInfluentialFactor)
train_new['LanguageOfCommunication'] = le.fit_transform(train_new.LanguageOfCommunication)
train_new['Gender'] = le.fit_transform(train_new.Gender)
train_new['HighestDegree'] = le.fit_transform(train_new.HighestDegree)
train_new['GraduatingInstitute'] = le.fit_transform(train_new.GraduatingInstitute)
train_new['CurrentDesignation'] = le.fit_transform(train_new.CurrentDesignation)
train_new['MartialStatus'] = le.fit_transform(train_new.MartialStatus)
train_new['CurrentCompanyType'] = le.fit_transform(train_new.CurrentCompanyType)
train_new['DepartmentInCompany'] = le.fit_transform(train_new.DepartmentInCompany)
train_new['JobProfileIDApplyingFor'] = le.fit_transform(train_new.JobProfileIDApplyingFor)
train_new['DegreeBranch'] = le.fit_transform(train_new.DegreeBranch)
train_new['GraduationYear'] = le.fit_transform(train_new.GraduationYear)

# %%
train_new.head(4)
# Out:
#    EmpID  EmpName  LanguageOfCommunication  Age  Gender  \
# 0  11041     John                        0   35       1
# 1  15079  William                        0   26       1
# 2  18638    James                        0   36       0
# 3   3941  Charles                        0   29       0
#
#    JobProfileIDApplyingFor  HighestDegree  DegreeBranch  GraduatingInstitute  \
# 0                        3              0             2                    0
# 1                        4              0             0                    2
# 2                        4              7             1                    0
# 3                        4              1             5                    1
#
#    LatestDegreeCGPA  ...  CurrentCTC  ExpectedCTC  MartialStatus  EmpScore  \
# 0                 7  ...          21           26              0         5
# 1                 7  ...          15           19              0         5
# ...

# %%
feature_cols = train_new.columns

# %%
feature_cols
# Out:
# Index(['EmpID', 'EmpName', 'LanguageOfCommunication', 'Age', 'Gender',
#        'JobProfileIDApplyingFor', 'HighestDegree', 'DegreeBranch',
#        'GraduatingInstitute', 'LatestDegreeCGPA', 'YearsOfExperince',
#        'GraduationYear', 'CurrentCTC', 'ExpectedCTC', 'MartialStatus',
#        'EmpScore', 'CurrentDesignation', 'CurrentCompanyType',
#        'DepartmentInCompany', 'TotalLeavesTaken', 'BiasInfluentialFactor',
#        'FitmentPercent'],
#       dtype='object')

# %%
train_csv.head(4)
# Out:
#    EmpID  EmpName  LanguageOfCommunication  Age  Gender  \
# 0  11041     John                        0   35       1
# 1  15079  William                        0   26       1
# 2  18638    James                        0   36       0
# 3   3941  Charles                        0   29       0
#
#    JobProfileIDApplyingFor  HighestDegree  DegreeBranch  GraduatingInstitute  \
# 0                        3              0             2                    0
# 1                        4              0             0                    2
# 2                        4              7             1                    0
# 3                        4              1             5                    1
#
#    LatestDegreeCGPA  ...  CurrentCTC  ExpectedCTC  MartialStatus  EmpScore  \
# 0                 7  ...          21           26              0         5
# 1                 7  ...          15           19              0         5
# ...

# %%
import xgboost
import csv as csv
from xgboost import plot_importance
from matplotlib import pyplot
from sklearn.model_selection import cross_val_score,KFold
from sklearn.model_selection import  train_test_split
from sklearn.metrics import mean_absolute_error
import matplotlib.pyplot as plt
from sklearn.model_selection import learning_curve, GridSearchCV
from scipy.stats import skew
from collections import OrderedDict

# %%
test_dataset = test_csv

# %%
test_dataset.head(4)
# Out:
#    EmpID  EmpName LanguageOfCommunication  Age Gender JobProfileIDApplyingFor  \
# 0   5664     Theo                  Native   35   Male                 JR85289
# 1  23568   Vernie                 English   35   Male                 JR85289
# 2  21490  Wendell                 English   28   Male                 JR87525
# 3   8363     West                   Hindi   37   Male                 JR87525
#
#   HighestDegree             DegreeBranch GraduatingInstitute  \
# 0           PhD   Information Technology              Tier 2
# 1        B.Tech   Information Technology              Tier 3
# 2        M.Tech  Artificial Intelligence              Tier 2
# 3            MS         Computer Science              Tier 2
#
#    LatestDegreeCGPA  YearsOfExperince  GraduationYear  CurrentCTC  \
# 0                 5                 5            2016          27
# 1                 9                12            2009          29
# 2                 9                 2            2019          18
# ...

# %%
test_final = pd.DataFrame()

# %%
test_final['EmpID'] =  test_dataset['EmpID']
test_final['EmpName']= test_dataset['EmpName']

# %%
test_final = test_dataset.drop(['EmpID','EmpName'], axis=1)

# %%
test_final.head(4)
# Out:
#   LanguageOfCommunication  Age Gender JobProfileIDApplyingFor HighestDegree  \
# 0                  Native   35   Male                 JR85289           PhD
# 1                 English   35   Male                 JR85289        B.Tech
# 2                 English   28   Male                 JR87525        M.Tech
# 3                   Hindi   37   Male                 JR87525            MS
#
#               DegreeBranch GraduatingInstitute  LatestDegreeCGPA  \
# 0   Information Technology              Tier 2                 5
# 1   Information Technology              Tier 3                 9
# 2  Artificial Intelligence              Tier 2                 9
# 3         Computer Science              Tier 2                 8
#
#    YearsOfExperince  GraduationYear  CurrentCTC  ExpectedCTC MartialStatus  \
# 0                 5            2016          27           34        Single
# 1                12            2009          29           33       Married
# ...

# %%
test_final['LanguageOfCommunication'] = le.fit_transform(test_final.LanguageOfCommunication)
test_final['Gender'] = le.fit_transform(test_final.Gender)
test_final['HighestDegree'] = le.fit_transform(test_final.HighestDegree)
test_final['GraduatingInstitute'] = le.fit_transform(test_final.GraduatingInstitute)
test_final['CurrentDesignation'] = le.fit_transform(test_final.CurrentDesignation)
test_final['MartialStatus'] = le.fit_transform(test_final.MartialStatus)
test_final['CurrentCompanyType'] = le.fit_transform(test_final.CurrentCompanyType)
test_final['DepartmentInCompany'] = le.fit_transform(test_final.DepartmentInCompany)
test_final['JobProfileIDApplyingFor'] = le.fit_transform(test_final.JobProfileIDApplyingFor)
test_final['DegreeBranch'] = le.fit_transform(test_final.DegreeBranch)
test_final['GraduationYear'] = le.fit_transform(test_final.GraduationYear)

# %%
test_final.head(4)
# Out:
#    LanguageOfCommunication  Age  Gender  JobProfileIDApplyingFor  \
# 0                        2   35       1                        3
# 1                        0   35       1                        3
# 2                        0   28       1                        4
# 3                        1   37       1                        4
#
#    HighestDegree  DegreeBranch  GraduatingInstitute  LatestDegreeCGPA  \
# 0              7             5                    1                 5
# 1              0             5                    2                 9
# 2              4             0                    1                 9
# 3              6             1                    1                 8
#
#    YearsOfExperince  GraduationYear  CurrentCTC  ExpectedCTC  MartialStatus  \
# 0                 5               7          27           34              1
# 1                12               0          29           33              0
# ...

# %%
test_final.columns
# Out:
# Index(['LanguageOfCommunication', 'Age', 'Gender', 'JobProfileIDApplyingFor',
#        'HighestDegree', 'DegreeBranch', 'GraduatingInstitute',
#        'LatestDegreeCGPA', 'YearsOfExperince', 'GraduationYear', 'CurrentCTC',
#        'ExpectedCTC', 'MartialStatus', 'EmpScore', 'CurrentDesignation',
#        'CurrentCompanyType', 'DepartmentInCompany', 'TotalLeavesTaken'],
#       dtype='object')

# %%
train_new.columns
# Out:
# Index(['LanguageOfCommunication', 'Age', 'Gender', 'JobProfileIDApplyingFor',
#        'HighestDegree', 'DegreeBranch', 'GraduatingInstitute',
#        'LatestDegreeCGPA', 'YearsOfExperince', 'GraduationYear', 'CurrentCTC',
#        'ExpectedCTC', 'MartialStatus', 'EmpScore', 'CurrentDesignation',
#        'CurrentCompanyType', 'DepartmentInCompany', 'TotalLeavesTaken',
#        'BiasInfluentialFactor', 'FitmentPercent'],
#       dtype='object')

# %%
name_id = pd.DataFrame()

# %%
name_id['EmpID'] =  train_new['EmpID']
name_id['EmpName']= train_new['EmpName']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'EmpID'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-252-2b583ee55b12> in <module>
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
train_new.drop(['EmpID','EmpName'], inplace=True,axis = 1)

# %%
np.random.seed(0)
df_train, df_test = train_test_split(train_new, train_size = 0.7, test_size = 0.3, random_state = 100)

# %%
df_train.head(4)
# Out:
#        LanguageOfCommunication  Age  Gender  JobProfileIDApplyingFor  \
# 301                          0   25       1                        1
# 12496                        0   31       0                        3
# 2424                         0   30       1                        3
# 7487                         0   33       1                        6
#
#        HighestDegree  DegreeBranch  GraduatingInstitute  LatestDegreeCGPA  \
# 301                0             0                    2                 7
# 12496              7             0                    2                 9
# 2424               2             4                    2                 5
# 7487               0             1                    1                 7
#
#        YearsOfExperince  GraduationYear  CurrentCTC  ExpectedCTC  \
# 301                   2              10          14           20
# 12496                 1              11          15           20
# ...

# %%
a = test_final.columns

# %%
from sklearn.metrics import classification_report

# %%
from sklearn.metrics import accuracy_score
import sklearn as sk
from sklearn import svm
import pandas as pd
import os

# %%
df_train.columns
# Out:
# Index(['LanguageOfCommunication', 'Age', 'Gender', 'JobProfileIDApplyingFor',
#        'HighestDegree', 'DegreeBranch', 'GraduatingInstitute',
#        'LatestDegreeCGPA', 'YearsOfExperince', 'GraduationYear', 'CurrentCTC',
#        'ExpectedCTC', 'MartialStatus', 'EmpScore', 'CurrentDesignation',
#        'CurrentCompanyType', 'DepartmentInCompany', 'TotalLeavesTaken',
#        'BiasInfluentialFactor'],
#       dtype='object')

# %%
for_fitment = train_new

# %%
df_train.head(4)
# Out:
#        LanguageOfCommunication  Age  Gender  JobProfileIDApplyingFor  \
# 301                          0   25       1                        1
# 12496                        0   31       0                        3
# 2424                         0   30       1                        3
# 7487                         0   33       1                        6
#
#        HighestDegree  DegreeBranch  GraduatingInstitute  LatestDegreeCGPA  \
# 301                0             0                    2                 7
# 12496              7             0                    2                 9
# 2424               2             4                    2                 5
# 7487               0             1                    1                 7
#
#        YearsOfExperince  GraduationYear  CurrentCTC  ExpectedCTC  \
# 301                   2              10          14           20
# 12496                 1              11          15           20
# ...

# %%
f = df_train
f.drop(['FitmentPercent'],axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-261-f91f149e66c2> in <module>
#       1 f = df_train
# ----> 2 f.drop(['FitmentPercent'],axis=1,inplace=True)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4172             level=level,
#    4173             inplace=inplace,
# -> 4174             errors=errors,
#    4175         )
#    4176
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3887         for axis, labels in axes.items():
#    3888             if labels is not None:
# -> 3889                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3890
#    3891         if inplace:
#
# ...

# %%
y_train = f.iloc[:,18]
x_train = f.iloc[:,:18]

# %%
for_fitment.columns
# Out:
# Index(['LanguageOfCommunication', 'Age', 'Gender', 'JobProfileIDApplyingFor',
#        'HighestDegree', 'DegreeBranch', 'GraduatingInstitute',
#        'LatestDegreeCGPA', 'YearsOfExperince', 'GraduationYear', 'CurrentCTC',
#        'ExpectedCTC', 'MartialStatus', 'EmpScore', 'CurrentDesignation',
#        'CurrentCompanyType', 'DepartmentInCompany', 'TotalLeavesTaken',
#        'BiasInfluentialFactor'],
#       dtype='object')

# %%
x_new_train = for_fitment.iloc[:,:18]
y_new_train = for_fitment.iloc[:,19]

# %%
x_new_train.head(4)
# Out:
#    LanguageOfCommunication  Age  Gender  JobProfileIDApplyingFor  \
# 0                        0   35       1                        3
# 1                        0   26       1                        4
# 2                        0   36       0                        4
# 3                        0   29       0                        4
#
#    HighestDegree  DegreeBranch  GraduatingInstitute  LatestDegreeCGPA  \
# 0              0             2                    0                 7
# 1              0             0                    2                 7
# 2              7             1                    0                 6
# 3              1             5                    1                 5
#
#    YearsOfExperince  GraduationYear  CurrentCTC  ExpectedCTC  MartialStatus  \
# 0                12               0          21           26              0
# 1                 3               9          15           19              0
# ...

# %%
ax_test = np.asarray(x_new_train)
ay_test = np.asarray(y_new_train)

# %%
ax_test
# Out:
# array([[ 0, 35,  1, ...,  0,  1, 20],
#        [ 0, 26,  1, ...,  1,  2,  6],
#        [ 0, 36,  0, ...,  1,  2, 19],
#        ...,
#        [ 1, 37,  1, ...,  0,  1, 20],
#        [ 1, 24,  1, ...,  1,  2,  7],
#        [ 0, 35,  1, ...,  2,  2, 16]])

# %%
ay_test
# Out:
# array([95.4 , 67.09, 91.26, ..., 61.46, 93.64, 93.52])

# %%
from sklearn import linear_model

# %%
regr = linear_model.LinearRegression()
regr.fit(ax_test, ay_test)
# Out:
# LinearRegression()

# %%
predicted= regr.predict(v)

# %%
predicted
# Out:
# array([69.95626491, 71.28237066, 78.4837383 , ..., 77.28093018,
#        64.75106938, 73.54876424])

# %%
test_final['FitmentPercent'] = predicted

# %%
model_new = svm.SVC(kernel='linear', gamma='auto',C=20)
model.fit(ax_test, ay_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-274-ab87b7365380> in <module>
#       1 model_new = svm.SVC(kernel='linear', gamma='auto',C=20)
# ----> 2 model.fit(ax_test, ay_test)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/svm/_base.py in fit(self, X, y, sample_weight)
#     162                                        accept_large_sparse=False)
#     163
# --> 164         y = self._validate_targets(y)
#     165
#     166         sample_weight = np.asarray([]
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/svm/_base.py in _validate_targets(self, y)
#     542     def _validate_targets(self, y):
#     543         y_ = column_or_1d(y, warn=True)
# --> 544         check_classification_targets(y)
#     545         cls, y = np.unique(y_, return_inverse=True)
#     546         self.class_weight_ = compute_class_weight(self.class_weight,
#
# ...

# %%
pred = model.predict(x_test)

# %%
x_train.head(4)
# Out:
#        LanguageOfCommunication  Age  Gender  JobProfileIDApplyingFor  \
# 301                          0   25       1                        1
# 12496                        0   31       0                        3
# 2424                         0   30       1                        3
# 7487                         0   33       1                        6
#
#        HighestDegree  DegreeBranch  GraduatingInstitute  LatestDegreeCGPA  \
# 301                0             0                    2                 7
# 12496              7             0                    2                 9
# 2424               2             4                    2                 5
# 7487               0             1                    1                 7
#
#        YearsOfExperince  GraduationYear  CurrentCTC  ExpectedCTC  \
# 301                   2              10          14           20
# 12496                 1              11          15           20
# ...

# %%
g = df_test

# %%
g.head(3)
# Out:
#        LanguageOfCommunication  Age  Gender  JobProfileIDApplyingFor  \
# 9706                         1   32       1                        4
# 13001                        1   30       1                        3
# 10164                        0   33       0                        3
#
#        HighestDegree  DegreeBranch  GraduatingInstitute  LatestDegreeCGPA  \
# 9706               0             4                    0                 8
# 13001              0             1                    0                 7
# 10164              1             1                    2                 8
#
#        YearsOfExperince  GraduationYear  CurrentCTC  ExpectedCTC  \
# 9706                  9               3          11           16
# 13001                 7               5           7           17
# 10164                10               2          28           35
#
#        MartialStatus  EmpScore  CurrentDesignation  CurrentCompanyType  \
# ...

# %%
g = df_test
y_test = g.iloc[:,18]
x_test = g.iloc[:,:18]

# %%
y_train
# Out:
# 301      3
# 12496    4
# 2424     8
# 7487     9
# 7256     7
#         ..
# 79       8
# 12119    8
# 8039     9
# 6936     4
# 5640     8
# Name: BiasInfluentialFactor, Length: 9551, dtype: int64

# %%
X = np.asarray(x_train)
Y = np.asarray(y_train)

# %%
Y
# Out:
# array([3, 4, 8, ..., 9, 4, 8])

# %%
x_test = np.asarray(x_test)
y_test = np.asarray(y_test)

# %%
model = svm.SVC(kernel='poly', degree=20)
model.fit(X, Y)
predictions_for_poly = model.predict(x_test)

# %%
print(classification_report(y_test,predictions_for_poly))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.36      0.37      0.37       355
#            1       0.52      0.47      0.49       884
#            2       0.30      0.19      0.23       203
#            3       0.07      0.06      0.07        93
#            4       0.74      0.84      0.79       756
#            5       0.58      0.56      0.57       180
#            6       0.18      0.10      0.13        88
#            7       0.24      0.12      0.16        75
#            8       0.42      0.50      0.46       986
#            9       0.77      0.65      0.71       474
#
#     accuracy                           0.53      4094
#    macro avg       0.42      0.39      0.40      4094
# weighted avg       0.52      0.53      0.52      4094

# %%
print(predictions_for_poly)
# Out:
# [8 8 0 ... 8 9 1]

# %%
model_new = svm.SVC(kernel='linear', gamma='auto',C=20)
model_new.fit(X, Y)
predictions_poly = model_new.predict(x_test)

# %%
print(predictions_poly)
# Out:
# [8 1 4 ... 8 9 1]

# %%
print(classification_report(y_test,predictions_poly))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.42      0.17      0.24       355
#            1       0.50      0.60      0.54       884
#            2       0.00      0.00      0.00       203
#            3       0.00      0.00      0.00        93
#            4       0.79      0.92      0.85       756
#            5       0.76      0.79      0.78       180
#            6       0.00      0.00      0.00        88
#            7       0.00      0.00      0.00        75
#            8       0.46      0.55      0.50       986
#            9       0.54      0.71      0.61       474
#
#     accuracy                           0.56      4094
#    macro avg       0.35      0.37      0.35      4094
# weighted avg       0.49      0.56      0.52      4094
# ...

# %%
v = np.asarray(test_final)

# %%
v
# Out:
# array([[ 2, 35,  1, ...,  0,  3, 18],
#        [ 0, 35,  1, ...,  0,  2,  8],
#        [ 0, 28,  1, ...,  2,  2, 18],
#        ...,
#        [ 0, 27,  1, ...,  2,  2, 12],
#        [ 0, 33,  1, ...,  0,  1, 10],
#        [ 2, 26,  2, ...,  2,  2, 10]])

# %%
predictions_for_poly = model.predict(v)

# %%
print(predictions_for_poly)
# Out:
# [0 1 1 ... 8 0 8]

# %%
predictions_poly = model_new.predict(v)

# %%
print(predictions_poly)
# Out:
# [8 9 1 ... 1 8 1]

# %%
subm_csv.head(5)
# Out:
#    EmpID BiasInfluentialFactor  FitmentPercent
# 0   5664         MaritalStatus           25.14
# 1  23568          DegreeBranch           91.44
# 2  21490         MartialStatus           76.92
# 3   8363         HighestDegree           77.92
# 4   6165                Gender           85.64

# %%
test_final['BiasInfluentialFactor'] = predictions_poly

# %%
test_final.head(4)
# Out:
#    LanguageOfCommunication  Age  Gender  JobProfileIDApplyingFor  \
# 0                        2   35       1                        3
# 1                        0   35       1                        3
# 2                        0   28       1                        4
# 3                        1   37       1                        4
#
#    HighestDegree  DegreeBranch  GraduatingInstitute  LatestDegreeCGPA  \
# 0              7             5                    1                 5
# 1              0             5                    2                 9
# 2              4             0                    1                 9
# 3              6             1                    1                 8
#
#    YearsOfExperince  GraduationYear  CurrentCTC  ExpectedCTC  MartialStatus  \
# 0                 5               7          27           34              1
# 1                12               0          29           33              0
# ...

# %%
list_of
# Out:
# Never                 3336
# DegreeBranch          2858
# Gender                2605
# YearsOfExperince      1561
# CurrentCompanyType    1174
# EmpScore               659
# HighestDegree          582
# Ethinicity             328
# MartialStatus          280
# LatestDegreeCGPA       262
# Name: BiasInfluentialFactor, dtype: int64

# %%
final_df = pd.DataFrame()

# %%
final_df['EmpID'] = test_csv['EmpID']
final_df['BiasInfluentialFactor'] = test_final['BiasInfluentialFactor']

# %%
final_df['FitmentPercent'] = test_final['FitmentPercent']

# %%
final_df['BiasInfluentialFactor'] = final_df['BiasInfluentialFactor'].map({0:'NA',
                                                                           1:'DegreeBranch',
                                                                           2:'Gender',
                                                                           3:'YearsOfExperince',
                                                                           4:'CurrentCompanyType',
                                                                           5:'EmpScore',
                                                                           6:'HighestDegree',
                                                                           7:'Ethinicity',
                                                                           8:'MartialStatus',
                                                                           9:'LatestDegreeCGPA'
                                                                          })

# %%
final_df
# Out:
#       EmpID BiasInfluentialFactor  FitmentPercent
# 0      5664         MartialStatus       69.956265
# 1     23568      LatestDegreeCGPA       71.282371
# 2     21490          DegreeBranch       78.483738
# 3      8363                    NA       66.007329
# 4      6165    CurrentCompanyType       89.520739
# ...     ...                   ...             ...
# 8740  14758    CurrentCompanyType       94.297140
# 8741  23544              EmpScore       80.130372
# 8742  16175          DegreeBranch       77.280930
# 8743  18458         MartialStatus       64.751069
# 8744  10036          DegreeBranch       73.548764
#
# [8745 rows x 3 columns]

# %%
final_df.to_csv("data.csv", index = False)

# %%
subm_csv
# Out:
#    EmpID BiasInfluentialFactor  FitmentPercent
# 0   5664         MaritalStatus           25.14
# 1  23568          DegreeBranch           91.44
# 2  21490         MartialStatus           76.92
# 3   8363         HighestDegree           77.92
# 4   6165                Gender           85.64
# 5  17679                   NaN           41.23
# 6   9715                   NaN           50.00
